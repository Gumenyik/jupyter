# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Завдання 1

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6      148             72             35        0  33.6   50
# 1              1       85             66             29        0  26.6   31
# 2              8      183             64              0        0  23.3   32
# 3              1       89             66             23       94  28.1   21
# 4              0      137             40             35      168  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10      101             76             48      180  32.9   63
# 764            2      122             70             27        0  36.8   27
# 765            5      121             72             23      112  26.2   30
# 766            1      126             60              0        0  30.1   47
# 767            1       93             70             31        0  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %% [markdown]
# Завдання 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    768 non-null    int64
#  1   Glucose        768 non-null    int64
#  2   BloodPressure  768 non-null    int64
#  3   SkinThickness  768 non-null    int64
#  4   Insulin        768 non-null    int64
#  5   BMI            768 non-null    float64
#  6   Age            768 non-null    int64
#  7   Outcome        768 non-null    int64
# dtypes: float64(1), int64(7)
# memory usage: 48.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI         Age     Outcome
# count  768.000000  768.000000  768.000000
# mean    31.992578   33.240885    0.348958
# std      7.884160   11.760232    0.476951
# min      0.000000   21.000000    0.000000
# 25%     27.300000   24.000000    0.000000
# 50%     32.000000   29.000000    0.000000
# ...

# %% [markdown]
# Завдання 4

# %%
df['Insulin'].replace(0, np.NaN, inplace=True)

# %%
df['Insulin']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       94.0
# 4      168.0
#        ...
# 763    180.0
# 764      NaN
# 765    112.0
# 766      NaN
# 767      NaN
# Name: Insulin, Length: 768, dtype: float64

# %% [markdown]
# Завдання 5

# %%
sum(pd.isnull(df['Insulin']) == 1)
# Out:
# 374

# %% [markdown]
# Завдання 6

# %%
df[['BMI', 'BloodPressure', 'SkinThickness', 'Glucose']] = df[['BMI', 'BloodPressure', 'SkinThickness', 'Glucose']].replace(0, np.NaN)

# %% [markdown]
# Завдання 7

# %%
sum(df.isnull().sum())
# Out:
# 652

# %%
df.isnull().sum()
# Out:
# Pregnancies        0
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# Age                0
# Outcome            0
# dtype: int64

# %% [markdown]
# Завдання 8

# %%
df.isnull().sum().plot.bar();

# %% [markdown]
# Завдання 9

# %%
df_1 = df.copy()

# %%
df_1.dropna(inplace=True)

# %%
df_1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# 6              3     78.0           50.0           32.0     88.0  31.0   26
# 8              2    197.0           70.0           45.0    543.0  30.5   53
# 13             1    189.0           60.0           23.0    846.0  30.1   59
# ..           ...      ...            ...            ...      ...   ...  ...
# 753            0    181.0           88.0           44.0    510.0  43.3   26
# 755            1    128.0           88.0           39.0    110.0  36.5   37
# 760            2     88.0           58.0           26.0     16.0  28.4   22
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 765            5    121.0           72.0           23.0    112.0  26.2   30
#
#      Outcome
# 3          0
# 4          1
# ...

# %% [markdown]
# Завдання 10

# %%
df_2 = df.copy()

# %%
df_2.dropna(subset=['SkinThickness'], inplace=True)

# %%
df_2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6    148.0           72.0           35.0      NaN  33.6   50
# 1              1     85.0           66.0           29.0      NaN  26.6   31
# 2              8    183.0           64.0            NaN      NaN  23.3   32
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 764            2    122.0           70.0           27.0      NaN  36.8   27
# 765            5    121.0           72.0           23.0    112.0  26.2   30
# 766            1    126.0           60.0            NaN      NaN  30.1   47
# 767            1     93.0           70.0           31.0      NaN  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %% [markdown]
# Завдання 11

# %%
df_3 = df.copy()

# %%
df_3.dropna(subset=['SkinThickness', 'Glucose'], inplace=True)

# %%
df_3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6    148.0           72.0           35.0      NaN  33.6   50
# 1              1     85.0           66.0           29.0      NaN  26.6   31
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# 6              3     78.0           50.0           32.0     88.0  31.0   26
# ..           ...      ...            ...            ...      ...   ...  ...
# 761            9    170.0           74.0           31.0      NaN  44.0   43
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 764            2    122.0           70.0           27.0      NaN  36.8   27
# 765            5    121.0           72.0           23.0    112.0  26.2   30
# 767            1     93.0           70.0           31.0      NaN  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %% [markdown]
# Завдання 12

# %%
df_4 = df.copy()

# %%
df_4.drop(['Insulin'], 1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  Age  Outcome
# 0              6    148.0           72.0           35.0  33.6   50        1
# 1              1     85.0           66.0           29.0  26.6   31        0
# 2              8    183.0           64.0            NaN  23.3   32        1
# 3              1     89.0           66.0           23.0  28.1   21        0
# 4              0    137.0           40.0           35.0  43.1   33        1
# ..           ...      ...            ...            ...   ...  ...      ...
# 763           10    101.0           76.0           48.0  32.9   63        0
# 764            2    122.0           70.0           27.0  36.8   27        0
# 765            5    121.0           72.0           23.0  26.2   30        0
# 766            1    126.0           60.0            NaN  30.1   47        1
# 767            1     93.0           70.0           31.0  30.4   23        0
#
# [768 rows x 7 columns]

# %% [markdown]
# Завдання 13

# %%
df_5 = df.copy()

# %%
df_5.fillna(value={'SkinThickness': df_5['SkinThickness'].median()}, inplace=True)

# %%
df_5
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6    148.0           72.0           35.0      NaN  33.6   50
# 1              1     85.0           66.0           29.0      NaN  26.6   31
# 2              8    183.0           64.0           29.0      NaN  23.3   32
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 764            2    122.0           70.0           27.0      NaN  36.8   27
# 765            5    121.0           72.0           23.0    112.0  26.2   30
# 766            1    126.0           60.0           29.0      NaN  30.1   47
# 767            1     93.0           70.0           31.0      NaN  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %% [markdown]
# Завдання 14

# %%
ax = df_5.plot.scatter(x="Glucose", y="SkinThickness",label="Gr1", c='Red')
df.plot.scatter(x="Glucose", y="SkinThickness", label="Gr1",ax=ax);

# %% [markdown]
# Завдання 15

# %%
df_6 = df.copy()

# %%
df_6.fillna(value={'Insulin': df_6['Insulin'].mean()}, inplace=True)

# %%
df_6
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0           35.0  155.548223  33.6
# 1              1     85.0           66.0           29.0  155.548223  26.6
# 2              8    183.0           64.0            NaN  155.548223  23.3
# 3              1     89.0           66.0           23.0   94.000000  28.1
# 4              0    137.0           40.0           35.0  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0           48.0  180.000000  32.9
# 764            2    122.0           70.0           27.0  155.548223  36.8
# 765            5    121.0           72.0           23.0  112.000000  26.2
# 766            1    126.0           60.0            NaN  155.548223  30.1
# 767            1     93.0           70.0           31.0  155.548223  30.4
#
#      Age  Outcome
# 0     50        1
# 1     31        0
# 2     32        1
# ...

# %% [markdown]
# Завдання 16

# %%
from scipy import stats

# %%
df_7 = df.copy()

# %%
func = stats.gaussian_kde(df_7.dropna(subset=['BloodPressure'])['BloodPressure'])

# %%
df_7
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6    148.0           72.0           35.0      NaN  33.6   50
# 1              1     85.0           66.0           29.0      NaN  26.6   31
# 2              8    183.0           64.0            NaN      NaN  23.3   32
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 764            2    122.0           70.0           27.0      NaN  36.8   27
# 765            5    121.0           72.0           23.0    112.0  26.2   30
# 766            1    126.0           60.0            NaN      NaN  30.1   47
# 767            1     93.0           70.0           31.0      NaN  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %%
df_7.fillna(value={'BloodPressure': pd.Series(func(df_7['BloodPressure']))}, inplace=True)

# %%
df_7
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  Age  \
# 0              6    148.0           72.0           35.0      NaN  33.6   50
# 1              1     85.0           66.0           29.0      NaN  26.6   31
# 2              8    183.0           64.0            NaN      NaN  23.3   32
# 3              1     89.0           66.0           23.0     94.0  28.1   21
# 4              0    137.0           40.0           35.0    168.0  43.1   33
# ..           ...      ...            ...            ...      ...   ...  ...
# 763           10    101.0           76.0           48.0    180.0  32.9   63
# 764            2    122.0           70.0           27.0      NaN  36.8   27
# 765            5    121.0           72.0           23.0    112.0  26.2   30
# 766            1    126.0           60.0            NaN      NaN  30.1   47
# 767            1     93.0           70.0           31.0      NaN  30.4   23
#
#      Outcome
# 0          1
# 1          0
# ...

# %%
ax = df_7.plot.scatter(x="Glucose", y="BloodPressure",label="Gr1", c='Red')
df.plot.scatter(x="Glucose", y="BloodPressure", label="Gr1",ax=ax);
